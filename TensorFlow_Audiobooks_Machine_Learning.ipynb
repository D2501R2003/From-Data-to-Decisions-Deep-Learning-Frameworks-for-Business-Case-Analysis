# %% [markdown]
# ### Create the machine learning algorithm

# %% [markdown]
# ##### Import the relevant libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# #### Data

# %%
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(float)
train_targets = npz['targets'].astype(int)

npz = np.load('Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

npz = np.load('Audiobooks_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# %% [markdown]
# #### Model

# %%
input_size = 10
output_size = 2
hidden_layer = 50

model = tf.keras.Sequential([
                            tf.keras.layers.Dense(hidden_layer, activation='relu'),
                            tf.keras.layers.Dense(hidden_layer, activation='relu'),
                            tf.keras.layers.Dense(output_size, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics = ['accuracy'])

batch_size = 100

max_epochs = 100

early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2)
model.fit(train_inputs,
          train_targets,
          batch_size=batch_size,
          epochs=max_epochs,
          callbacks=[early_stopping],
          validation_data=(validation_inputs, validation_targets),
          verbose=2)
# Out:
# Epoch 1/100
# 36/36 - 6s - 174ms/step - accuracy: 0.6876 - loss: 0.6006 - val_accuracy: 0.7651 - val_loss: 0.5022
# Epoch 2/100
# 36/36 - 1s - 20ms/step - accuracy: 0.7728 - loss: 0.4749 - val_accuracy: 0.8076 - val_loss: 0.4188
# Epoch 3/100
# 36/36 - 1s - 20ms/step - accuracy: 0.7896 - loss: 0.4181 - val_accuracy: 0.8054 - val_loss: 0.3856
# Epoch 4/100
# 36/36 - 1s - 18ms/step - accuracy: 0.7997 - loss: 0.3897 - val_accuracy: 0.8076 - val_loss: 0.3749
# Epoch 5/100
# 36/36 - 1s - 18ms/step - accuracy: 0.8036 - loss: 0.3763 - val_accuracy: 0.8121 - val_loss: 0.3609
# Epoch 6/100
# 36/36 - 1s - 21ms/step - accuracy: 0.8075 - loss: 0.3664 - val_accuracy: 0.8098 - val_loss: 0.3542
# Epoch 7/100
# 36/36 - 1s - 20ms/step - accuracy: 0.8061 - loss: 0.3580 - val_accuracy: 0.8098 - val_loss: 0.3522
# Epoch 8/100
# 36/36 - 1s - 18ms/step - accuracy: 0.8106 - loss: 0.3530 - val_accuracy: 0.8009 - val_loss: 0.3487
# Epoch 9/100
# 36/36 - 1s - 18ms/step - accuracy: 0.8097 - loss: 0.3500 - val_accuracy: 0.8255 - val_loss: 0.3453
# Epoch 10/100
# 36/36 - 1s - 19ms/step - accuracy: 0.8083 - loss: 0.3467 - val_accuracy: 0.7897 - val_loss: 0.3479
# Epoch 11/100
# 36/36 - 1s - 19ms/step - accuracy: 0.8117 - loss: 0.3439 - val_accuracy: 0.8210 - val_loss: 0.3391
# Epoch 12/100
# 36/36 - 1s - 22ms/step - accuracy: 0.8128 - loss: 0.3419 - val_accuracy: 0.8300 - val_loss: 0.3381
# Epoch 13/100
# 36/36 - 1s - 18ms/step - accuracy: 0.8125 - loss: 0.3415 - val_accuracy: 0.8166 - val_loss: 0.3384
# Epoch 14/100
# 36/36 - 1s - 19ms/step - accuracy: 0.8209 - loss: 0.3381 - val_accuracy: 0.8255 - val_loss: 0.3360
# Epoch 15/100
# 36/36 - 1s - 19ms/step - accuracy: 0.8175 - loss: 0.3353 - val_accuracy: 0.8121 - val_loss: 0.3358
# Epoch 16/100
# 36/36 - 1s - 28ms/step - accuracy: 0.8173 - loss: 0.3368 - val_accuracy: 0.8143 - val_loss: 0.3347
# Epoch 17/100
# 36/36 - 1s - 19ms/step - accuracy: 0.8198 - loss: 0.3333 - val_accuracy: 0.8300 - val_loss: 0.3314
# Epoch 18/100
# 36/36 - 1s - 19ms/step - accuracy: 0.8159 - loss: 0.3333 - val_accuracy: 0.8233 - val_loss: 0.3323
# Epoch 19/100
# 36/36 - 1s - 19ms/step - accuracy: 0.8181 - loss: 0.3354 - val_accuracy: 0.8255 - val_loss: 0.3366

# %% [markdown]
# ### Test the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8504 - loss: 0.3001

# %%
print("\n Test loss: {0:.2f}. Test accuracy: {1:.2f}%".format(test_loss, test_accuracy*100.))
# Out:
#  Test loss: 0.30. Test accuracy: 85.04%
